# %%
# %matplotlib inline 

import sympy as sym
import numpy as np
import matplotlib.pylab as plt
import random

from sympy import init_printing; init_printing(use_latex='mathjax')
from IPython.display import display
from IPython.display import HTML
from scipy.integrate import odeint
from ipywidgets import *

from sympy import*
import pandas as pd

# %%
X_0= 0
elements=[1,-1]
probabilitis=[0.8,0.2]
delta_x= np.random.choice(elements,100,probabilitis)
y= np.ones(len(np.cumsum(delta_x)))
#plt.plot(np.cumsum(delta_x),y
plt.plot(np.cumsum(delta_x))

# %%
def walker ():
    global x,y
    eleccion =random.randint(0,3)
    if eleccion == 0:
        x+=1
    if eleccion == 1:
        x-=1
    if eleccion == 2:
        y+=1
    else:
        y-=1
    return [x,y]
x=0
y=0
Pos=np.zeros((2,1000))

for i in np.arange(0,len(Pos[0]),1):
    Pos[:,i]= walker()
    
plt.plot(Pos[0,:],Pos[1,:], "bo-")
plt.plot(Pos[0,-1],Pos[1,-1], "ro-")

# %%
def walker ():
    global x,y
    x +=random.randint(-1,1)
    y +=random.randint(-1,1)
    return [x,y]
x=0
y=0
Pos=np.zeros((2,1000))

for i in np.arange(0,len(Pos[0]),1):
    Pos[:,i]= walker()
    
plt.plot(Pos[0,:],Pos[1,:], "bo-")
plt.plot(Pos[0,-1],Pos[1,-1], "ro-")

# %%
def walker ():
    global x,y
    x +=random.uniform(-1,1)
    y +=random.uniform(-1,1)
    return [x,y]
x=0
y=0
Pos=np.zeros((2,1000))

for i in np.arange(0,len(Pos[0]),1):
    Pos[:,i]= walker()
    
plt.plot(Pos[0,:],Pos[1,:], "bo-")
plt.plot(Pos[0,-1],Pos[1,-1], "ro-")

# %%
x_0=np.array([[0],[0]])
delta_x= np.random.uniform(-1,1,(2,1000))

x= np.concatenate((x_0,np.cumsum(delta_x,axis=1)),axis=1)
rw=plt.plot(x[0],x[1],"ro-")

# %%
plt.hist(np.random.normal(0,1,(1000,1)))
# Out:
# (array([   4.,   21.,   86.,  175.,  238.,  236.,  144.,   64.,   24.,    8.]),
#  array([-3.09748485, -2.4693077 , -1.84113055, -1.21295341, -0.58477626,
#          0.04340089,  0.67157804,  1.29975519,  1.92793234,  2.55610949,
#          3.18428664]),
#  <a list of 10 Patch objects>)

# %%
def walker ():
    global x,y
    eleccion =random.randint(0,3)
    if eleccion <0.4:
        x+=1
    elif eleccion <0.6:
        x-=1
    elif eleccion <0.8:
        y+=1
    else:
        y-=1
    return [x,y]
x=0
y=0
Pos=np.zeros((2,1000))

for i in np.arange(0,len(Pos[0]),1):
    Pos[:,i]= walker()
    
plt.plot(Pos[0,:],Pos[1,:], "bo-")
plt.plot(Pos[0,-1],Pos[1,-1], "ro-")

# %%
def walker ():
    global x,y
    eleccion =random.randint(0,3)
    if eleccion <0.1:
        x+=1
    elif eleccion <0.2:
        x-=1
    elif eleccion <0.6:
        y+=1
    else:
        y-=1
    return [x,y]
x=0
y=0
Pos=np.zeros((2,100))

for i in np.arange(0,len(Pos[0]),1):
    Pos[:,i]= walker()
    
plt.plot(Pos[0,:],Pos[1,:], "bo-")
plt.plot(Pos[0,-1],Pos[1,-1], "ro-")

# %%
def walker ():
    global x,y
    x +=np.random.normal(0,2000)
    y +=random.gauss(0,2000)
    return [x,y]
x=0
y=0

Pos=np.zeros((2,100))

for i in np.arange(0,len(Pos[0]),1):
    Pos[:,i]= walker()
    
plt.plot(Pos[0,:],Pos[1,:], "bo-")
plt.plot(Pos[0,-1],Pos[1,-1], "ro-")

# %%
def walker ():
    global x,y
    r=random.uniform(0,1)
    if r< 0.01:
        x +=np.random.normal(0,200)
        y +=random.gauss(0,200)
    else:
        x +=np.random.normal(0,1)
        y +=random.gauss(0,1)
    return [x,y]
x=0
y=0

Pos=np.zeros((2,1000))

for i in np.arange(0,len(Pos[0]),1):
    Pos[:,i]= walker()
    
plt.plot(Pos[0,:],Pos[1,:], "bo-")
plt.plot(Pos[0,-1],Pos[1,-1], "ro-")

# %%
inicio=np.array([[0],[0]])
elements=np.array([[1,-1,0,0],[0,0,1,-1]])
probabilities= [0.4, 0.2,0.2,0.2]

pasos= elements[:,np.random.choice(elements.shape[1],10000,probabilities)]
pasos= np.concatenate((inicio,pasos),axis=1)

Pos=np.cumsum(pasos,axis=1)
plt.plot(Pos[0,:],Pos[1,:],"bo-")
