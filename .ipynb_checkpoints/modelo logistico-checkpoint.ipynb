# %%
import numpy as np
from scipy.integrate import odeint
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import matplotlib as mpl
label_size = 14
mpl.rcParams['xtick.labelsize'] = label_size 
mpl.rcParams['ytick.labelsize'] = label_size

# %%
r = 1
def poblacion(x, t):
    return r * x * (1 - x)

# %%
x0 = 0.05
tt = np.linspace(0, 10)
xx = odeint(poblacion, x0, tt)
for r in np.arange(-1, 1,.1):
    plt.plot(tt,odeint(poblacion, x0, tt)) 
plt.xlabel('$t$', fontsize = 18)
plt.ylabel('$x$', fontsize = 18)
plt.show()

# %%
def logi_sol(t, x0, r):
    return 1/(1 + (1/x0 - 1) * np.exp(-r * t))

# %%
t = np.linspace(0,10)
for r in np.arange(-1, 1,.1):
    plt.plot(t, logi_sol(t, 0.05, r))
plt.xlabel('$t$', fontsize = 18)
plt.ylabel('$x$', fontsize = 18)
plt.show()

# %%
k = 2
def ecua(x,P):
    return 2*P

# %%
x0 = 10
tt = np.linspace(0, 10)
xx = odeint(ecua, x0, tt)
for r in np.arange(-1, 1,.1):
    plt.plot(tt,odeint(ecua, x0, tt)) 
plt.xlabel('$t$', fontsize = 18)
plt.ylabel('$x$', fontsize = 18)
plt.show()

# %%
def logi_sol(t,P):
    return P*np.exp(2*t)

# %%
P=10
t = np.linspace(0,10)
for r in np.arange(-1, 1,.1):
    plt.plot(t,logi_sol(t,P))
plt.xlabel('$t$', fontsize = 18)
plt.ylabel('$x$', fontsize = 18)
plt.show()

# %%
import numpy as np
def mapa_logistico(r,x):
    return r*x*(1-x)

# %% [markdown]
# r=3.1
# n=100
# x=np.zeros(n)
# x{0}0.3
#
# for i in range (n-1)

# %%
r=3.99
n=100
x=np.zeros(n)
x[0]=0.3

for i in range (n-1):
    x[i+1]= mapa_logistico(r,x[i])
plt.plot(np.arange(0,n),x)
