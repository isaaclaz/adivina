# %%
# %matplotlib inline 

import sympy as sym
import numpy as np
import matplotlib.pylab as plt
import random

from sympy import init_printing; init_printing(use_latex='mathjax')
from IPython.display import display
from IPython.display import HTML
from scipy.integrate import odeint
from ipywidgets import *

# %%
X_0= 0
elements=[1,-1]
probabilitis=[0.8,0.2]
delta_x= np.random.choice(elements,100,probabilitis)
y= np.ones(len(np.cumsum(delta_x)))
#plt.plot(np.cumsum(delta_x),y
plt.plot(np.cumsum(delta_x))

# %%
def walker ():
    global x,y
    eleccion =random.randint(0,3)
    if eleccion == 0:
        x+=1
    if eleccion == 1:
        x-=1
    if eleccion == 2:
        y+=1
    else:
        y-=1
    return [x,y]
x=0
y=0
Pos=np.zeros((2,1000))

for i in np.arange(0,len(Pos[0]),1):
    Pos[:,i]= walker()
    
plt.plot(Pos[0,:],Pos[1,:], "bo-")
plt.plot(Pos[0,-1],Pos[1,-1], "ro-")

# %%
def walker ():
    global x,y
    x +=random.randint(-1,1)
    y +=random.randint(-1,1)
    return [x,y]
x=0
y=0
Pos=np.zeros((2,1000))

for i in np.arange(0,len(Pos[0]),1):
    Pos[:,i]= walker()
    
plt.plot(Pos[0,:],Pos[1,:], "bo-")
plt.plot(Pos[0,-1],Pos[1,-1], "ro-")

# %%
def walker ():
    global x,y
    x +=random.uniform(-1,1)
    y +=random.uniform(-1,1)
    return [x,y]
x=0
y=0
Pos=np.zeros((2,1000))

for i in np.arange(0,len(Pos[0]),1):
    Pos[:,i]= walker()
    
plt.plot(Pos[0,:],Pos[1,:], "bo-")
plt.plot(Pos[0,-1],Pos[1,-1], "ro-")

# %%
x_0=np.array([[0],[0]])
delta_x= np.random.uniform(-1,1,(2,1000))

x= np.concatenate((x_0,np.cumsum(delta_x,axis=1)),axis=1)
rw=plt.plot(x[0],x[1],"ro-")

# %%
plt.hist(np.random.normal(0,1,(1000,1)))
# Out:
# (array([   3.,   18.,   88.,  214.,  301.,  248.,   95.,   29.,    3.,    1.]),
#  array([-3.57548472, -2.78180018, -1.98811564, -1.19443109, -0.40074655,
#          0.39293799,  1.18662254,  1.98030708,  2.77399163,  3.56767617,
#          4.36136071]),
#  <a list of 10 Patch objects>)

# %%
def walker ():
    global x,y
    eleccion =random.randint(0,3)
    if eleccion <0.4:
        x+=1
    elif eleccion <0.6:
        x-=1
    elif eleccion <0.8:
        y+=1
    else:
        y-=1
    return [x,y]
x=0
y=0
Pos=np.zeros((2,1000))

for i in np.arange(0,len(Pos[0]),1):
    Pos[:,i]= walker()
    
plt.plot(Pos[0,:],Pos[1,:], "bo-")
plt.plot(Pos[0,-1],Pos[1,-1], "ro-")

# %%
def walker ():
    global x,y
    eleccion =random.randint(0,3)
    if eleccion <0.1:
        x+=1
    elif eleccion <0.2:
        x-=1
    elif eleccion <0.6:
        y+=1
    else:
        y-=1
    return [x,y]
x=0
y=0
Pos=np.zeros((2,100))

for i in np.arange(0,len(Pos[0]),1):
    Pos[:,i]= walker()
    
plt.plot(Pos[0,:],Pos[1,:], "bo-")
plt.plot(Pos[0,-1],Pos[1,-1], "ro-")

# %%
def walker ():
    global x,y
    x +=np.random.normal(0,2000)
    y +=random.gauss(0,2000)
    return [x,y]
x=0
y=0

Pos=np.zeros((2,100))

for i in np.arange(0,len(Pos[0]),1):
    Pos[:,i]= walker()
    
plt.plot(Pos[0,:],Pos[1,:], "bo-")
plt.plot(Pos[0,-1],Pos[1,-1], "ro-")

# %%
def walker ():
    global x,y
    r=random.uniform(0,1)
    if r< 0.01:
        x +=np.random.normal(0,200)
        y +=random.gauss(0,200)
    else:
        x +=np.random.normal(0,1)
        y +=random.gauss(0,1)
    return [x,y]
x=0
y=0

Pos=np.zeros((2,1000))

for i in np.arange(0,len(Pos[0]),1):
    Pos[:,i]= walker()
    
plt.plot(Pos[0,:],Pos[1,:], "bo-")
plt.plot(Pos[0,-1],Pos[1,-1], "ro-")
